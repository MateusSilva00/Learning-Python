# %%
import xlrd
import seaborn as sns
import matplotlib.pyplot as fig
import yfinance as yf
import numpy as ny

wb = xlrd.open_workbook('EstatDad.xls')
plan = wb.sheet_by_name('Plan3')

lin = plan.nrows
col = plan.ncols

dados = []

for i in range(col):
    coluna = plan.col_values(i)
    dados.append(coluna)

sns.boxplot(data=dados)
sns.stripplot(data=dados, marker='o', color="black")
# Out:
# <AxesSubplot:>

# %%
fig.figure()
fig.subplot(221)
sns.distplot(dados[0], color="black")
fig.ylabel("AMOSTRRA 1", fontsize=14)

fig.subplot(222)
sns.distplot(dados[1], color="black")
fig.ylabel("AMOSTRRA 2", fontsize=14)

fig.subplot(223)
sns.distplot(dados[2], color="black")
fig.ylabel("AMOSTRRA 3", fontsize=14)

fig.subplot(224)
sns.distplot(dados[3], color="black")
fig.ylabel("AMOSTRRA 4", fontsize=14)
# Out:
# C:\Users\mateu\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\mateu\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
fig.figure()
fig.subplot(221)
sns.violinplot(dados[0], color='grey')
fig.ylabel("Amostra 1", fontsize=14)

fig.subplot(222)
sns.violinplot(dados[1], color='grey')
fig.ylabel("Amostra 2", fontsize=14)

fig.subplot(223)
sns.violinplot(dados[2], color='grey')
fig.ylabel("Amostra 3", fontsize=14)

fig.subplot(224)
sns.violinplot(dados[3], color='grey')
fig.ylabel("Amostra 4", fontsize=14)
# Out:
# C:\Users\mateu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mateu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mateu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
tickersList = ["PETR3.SA", "VALE3.SA","^BVSP"]

# Downloading the data for the file, only adjusted close
data = yf.download(tickersList, period="1y")["Adj Close"]

petrobras = data["PETR3.SA"]
vale = data["VALE3.SA"]
ibov = data["^BVSP"]
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
retPetrobras = petrobras.pct_change()
retVale = vale.pct_change()
retIbov = ibov.pct_change()

eixoX = ny.arange(len(petrobras))
eixoRet = ny.arange(len(retIbov))



fig.figure(figsize=(12,8))
ax1 = fig.subplot(111)
ax1.plot(eixoX, ibov, '-k')
ax1.set_xlabel("Dias", fontsize=14)
ax1.set_ylabel("Ibovespa")
ax1_segundo = ax1.twinx()
ax1_segundo.plot(eixoX, petrobras, '--k', eixoX, vale, '.-k')
# Out:
# No handles with labels found to put in legend.
# ...

# %%
fig.figre()
# Out:
# Date
# 2020-11-24    24.533918
# 2020-11-25    24.369385
# 2020-11-26    23.994610
# 2020-11-27    23.674683
# 2020-11-30    23.354753
# Name: PETR3.SA, dtype: float64
