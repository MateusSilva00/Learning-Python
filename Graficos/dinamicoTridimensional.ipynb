# %%
import numpy as np
import time
import matplotlib.pyplot as fig
import random

fig.style.use("ggplot")
ax1=fig.subplot(211)
ax2=fig.subplot(212)
xar=[]
ret=[]
lin=10

#Não funcionou no jupyterweb
x = np.zeros(lin)
retorno = np.zeros(lin)
for j in range(lin):
    x[j] = random.gauss(0,1)
    if j > 0:
        retorno[j] = (x[j] - x[j-1])/ x[j-1]
    print('%d %5.2f'% (j, x[j]))
    xar.append(x[j])
    ret.append(retorno[j])
    ax1.plot(xar, '-ok')
    ax2.plot(ret, '-ok')
    fig.pause(0.5)
    time.sleep(1)
# Out:
# 0 -0.03
# 1 -1.87
# 2 -0.65
# 3 -2.01
# 4  0.99
# 5  0.34
# 6 -0.29
# 7  0.11
# 8 -1.07
# 9  1.41

# %%
from mpl_toolkits import mplot3d

ax=fig.axes(projection='3d')
z=np.linspace(0,15, 1000)
x=np.sin(z)
y=np.cos(z)
ax.plot3D(x,y,z, 'gray')


dadZ = 15*np.random.randn(100)
dadX = np.sin(dadZ) + 0.2*np.random.randn(100)
dadY = np.cos(dadZ) + 0.2*np.random.randn(100)
ax.scatter3D(dadX, dadY, dadZ, c=dadZ, cmap='Purples')
ax.set_xlabel("Eixo x")
ax.set_ylabel("Eixo y")
ax.set_zlabel("Eixo z")
# Out:
# Text(0.5, 0, 'Eixo z')

# %%
ax=fig.axes(projection='3d')
x = np.linspace(-20,20,50)
y = np.linspace(-20,20,50)
X, Y = np.meshgrid(x,y)
Z = np.sin(np.sqrt(X ** 2 + Y ** 2))
ax.contour3D(X,Y,Z,50, cmap='Greys')

ax.set_xlabel("Eixo x")
ax.set_ylabel("Eixo y")
ax.set_zlabel("Eixo z")
# Out:
# Text(0.5, 0, 'Eixo z')

# %%
ax=fig.axes(projection='3d')
x = np.linspace(-2,2,50)
y = np.linspace(-2,2,50)

X, Y = np.meshgrid(x,y)
Z = np.sin(np.sqrt(X ** 2 + Y ** 2))
ax.contour3D(X,Y,Z,50, cmap='Greys')

ax.set_xlabel("Eixo x")
ax.set_ylabel("Eixo y")
ax.set_zlabel("Eixo z")
# Out:
# Text(0.5, 0, 'Eixo z')
