# %%
import matplotlib.pyplot as fig
x = [0, 1, 2, 3]
y = [2, 5, 8, 10]
z = [3, 3, 1, 2]
w = [10, 3, 2, 1]
fig.plot(x,y, '-k', x, z,'-or', x, w, '-*b', markersize=12)
fig.xlabel("Eixo x")
fig.ylabel("Eixo y")
fig.title("Gráfico teste")
fig.grid(True)
fig.text(x=2, y=2.5, s='Curva Z', fontsize=16)
# Out:
# Text(2, 2.5, 'Curva Z')

# %%
x = [0,1,2,3,4,5,6]
y = [2,5,8,10,8,3,1]
z = [-2,-1,3,4,5,0,-1]

fig.figure(figsize=(12,8))
ax = fig.subplot(111)
g1 = ax.plot(x,y, '-*k', markersize=14)
g2 = ax.plot(x,z, '-vk', markersize=14)
ax.legend(['y', 'z'], loc='upper right')
ax.set_xlim(0,6)
ax.set_xlabel("Eixo x", fontsize=14, weight="bold")
ax.set_ylabel("Eixo y", fontsize=14, weight="bold")
ax.set_ylim(-10, 15)
ax.set_xticks(x)
ax.set_yticks([-2,-1.5,-1,-0.5,0, 0.5, 1, 1.5,2,2.5,3,3.5,4,5,6,8,10])
ax.grid(True)
ax.set_title("++++++++++++++++++ GRÁFICO COM PROPRIEDADES DOS EXISO ++++++++++++++++++")
ax.text(x=5, y=4, s='var y', fontsize=12, color='k', weight='bold')
# Out:
# Text(5, 4, 'var y')

# %%
fig.style.use('ggplot')
x = ['Ação', 'Petróleo', 'Dólar', 'Opções', 'Commodity', 'Títulos', 'Bitcoin']
y = [2,5,8,10,8,3,1]

fig.figure(figsize=(14,8))
ax=fig.subplot(221)
ax.bar(x, y)

ax=fig.subplot(222)
ax.barh(x,y,color='black', alpha=1)

ax=fig.subplot(223)
explodir=(0,0,0,0.2,0,0,0)

ax.pie(y, explode=explodir, labels=x, autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x17dd404a970>,
# ...
#  [Text(1.0841775006180574, 0.18590090681215662, 'Ação'),
#   Text(0.794151711535522, 0.761132747334656, 'Petróleo'),
#   Text(-0.32210503443139143, 1.0517834124923022, 'Dólar'),
#   Text(-1.2580528424109805, -0.32757143602831523, 'Opções'),
#   Text(0.23174713645253114, -1.0753107758904177, 'Commodity'),
#   Text(1.0023513162097888, -0.45309142443054956, 'Títulos'),
#   Text(1.0960372317461595, -0.09328658331301243, 'Bitcoin')],
#  [Text(0.5913695457916677, 0.1014004946248127, '5.41%'),
#   Text(0.43317366083755743, 0.41516331672799417, '13.51%'),
#   Text(-0.1756936551443953, 0.5737000431776192, '21.62%'),
#   Text(-0.7741863645606033, -0.20158242217127087, '27.03%'),
#   Text(0.12640752897410787, -0.5865331504856823, '21.62%'),
#   Text(0.5467370815689756, -0.24714077696211792, '8.11%'),
#   Text(0.5978384900433596, -0.05088359089800678, '2.70%')])
